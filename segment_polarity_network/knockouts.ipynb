# %% [markdown]
# # Determine which interactions are key to generating the stable states

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from functools import reduce
import random

# %%
import pickle
from collections import Counter
from itertools import combinations
import interactions
import initialize
from util import action_set, to_action, format_actions
from action import Action

# %%
from segment_polarity_model import SegmentPolarityModel
from tree_search import SearchState
import attractors

# %%
from joblib import Parallel, delayed

# %%
datadir='/home/bglaze/segment_polarity/data'
tmstp='20210415-1427'
f = open(f'{datadir}/models/best_models/best_models_clusters_tmstp-{tmstp}.pickle','rb')

clusters = pickle.load(f)

# %%
# Remove all interactions corresponding to a specific action from the rules of a given model
def knockout_interactions(model, knockouts):
    if type(knockouts) is Action:
        raise TypeError(f'knockouts argument must be a list of Actions, got {type(knockouts)}')
    
    knockout_model = dict()
    
    for dst, (act, inh) in model.rules.items():
        knockout_model[dst] = ([], []) 
        dst_node, dst_cell = dst
        for src in act:
            action = to_action(src,dst,'a')
            if action not in knockouts:
                knockout_model[dst][0].append(src)
        for src in inh:
            action = to_action(src,dst,'i')
            if action not in knockouts:
                knockout_model[dst][1].append(src)
    return SegmentPolarityModel(knockout_model)

# %% [markdown]
# ### Common Interactions

# %%
predefined,_ = initialize.initialState()

predefined = action_set(predefined.rules)

# %%
predefined
# Out:
# {Action(srcs=(('CI', 'i'),), dst='CIA', type='a'),
#  Action(srcs=(('CI', 'i'),), dst='CIR', type='a'),
#  Action(srcs=(('HH', 'e'),), dst='CIR', type='i'),
#  Action(srcs=(('PTC', 'i'), ('HH', 'e')), dst='PH', type='a'),
#  Action(srcs=(('PTC', 'i'), ('~HH', 'e')), dst='PTC', type='a'),
#  Action(srcs=(('WG', 'e'),), dst='en', type='a'),
#  Action(srcs=(('ci', 'i'),), dst='CI', type='a'),
#  Action(srcs=(('en', 'i'),), dst='EN', type='a'),
#  Action(srcs=(('hh', 'i'),), dst='HH', type='a'),
#  Action(srcs=(('ptc', 'i'),), dst='PTC', type='a'),
#  Action(srcs=(('wg', 'i'),), dst='WG', type='a'),
#  Action(srcs=(('~PTC', 'i'),), dst='SMO', type='a')}

# %%
import reference_model

# %%
reference_actions = set(reference_model.actions)

# %%
all_models = []
for cluster, models in clusters.items():
    all_models += models
print(len(all_models))
# Out:
# 50000

# %%
common_interactions = interactions.common(all_models, order=[1], verbose=True)
# Out:
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%

# %%
header = '% models | matches reference? | interaction'

i=0
print(header)
for actions,pct in sorted(list(common_interactions.items()), key=lambda _:_[1], reverse=True):
    action = actions[0]
    if action not in predefined: 
        print(f'{pct*100:3.0f}% {"x" if action in reference_actions else " "}', end=' ')
        format_actions(actions)
        if i==50:
            break
        i+=1
# Out:
# % models | matches reference? | interaction
# 100% x (EN_i inhibit ci)
# 100%   (CIR_i inhibit CIA)
#  85% x (SLP_i inhibit en)
#  74% x (CIA_i and SLP_i activate wg)
#  72%   (EN_i inhibit CI)
#  59% x (CIA_i activate ptc)
#  51%   (CI_i inhibit hh)
#  51% x (EN_i activate hh)
#  43%   (CIR_i inhibit WG)
#  41%   (CI_i and SMO_i activate ptc)
#  41% x (CIR_i inhibit wg)
#  40% x (HH_{i+-1} activate SMO)
#  37%   (SLP_i inhibit hh)
#  35%   (EN_i activate HH)
#  34% x (SLP_i and wg_i activate wg)
#  34%   (CIA_i activate SMO)
#  34%   (CIR_i inhibit SMO)
#  32%   (CIA_i activate PTC)
#  27%   (EN_i inhibit PTC)
#  27%   (WG_i activate SMO)
#  26%   (WG_i activate CI)
#  25%   (CIA_i and SLP_i activate CI)
#  25%   (PH_i inhibit EN)
#  25%   (EN_i inhibit wg)
#  24%   (WG_i activate CIA)
#  24%   (PTC_i inhibit HH)
#  23%   (PH_i activate SMO)
#  23%   (PTC_i activate CIR)
#  23% x (CI_i and SMO_i activate CIA)
#  22% x (EN_i inhibit ptc)
#  22%   (PH_i activate PTC)
#  22%   (HH_i activate SMO)
#  21%   (CIA_i activate CIR)
#  20%   (CIA_i activate CI)
#  20%   (CIR_i inhibit PH)
#  20% x (CIR_i inhibit hh)
#  20%   (CIR_i inhibit en)
#  20%   (SLP_i activate CIA)
#  19%   (WG_i inhibit EN)
#  18%   (HH_i inhibit PTC)
#  18%   (CI_i and SMO_i inhibit CIR)
#  18% x (SMO_i inhibit CIR)
#  17%   (CI_i inhibit en)
#  17%   (CIA_i and SLP_i activate CIR)
#  17%   (HH_i inhibit PH)
#  17%   (PH_i inhibit CIR)
#  16%   (SLP_i inhibit EN)
#  16%   (CI_i activate PTC)
#  16% x (CIA_i and wg_i activate wg)
#  16% x (CIR_i inhibit ptc)
#  16%   (CIA_i and SLP_i inhibit hh)

# %% [markdown]
# ### Interactions unique to each cluster

# %% [markdown]
# #### First order (individual interactions)

# %%
unique_interactions = interactions.unique(clusters,
                                          uniqueness_threshold=.95, 
                                          order=[1],
                                          verbose=False)

# %%
for cluster in unique_interactions:
    print(cluster, len(unique_interactions[cluster]))
# Out:
# 0 3
# 1 1
# 2 2
# 3 1
# 4 0
# 5 0
# 6 0
# 7 1
# 8 2
# 9 1
# 10 2

# %% [markdown]
# #### Higher order (n-tuples of interactions)

# %%
unique_interactions = interactions.unique(clusters,
                                          uniqueness_threshold=.90, 
                                          order=[1,2,3,4,5],
                                          verbose=True,
                                          excluded=predefined
                                         )
# Out:
# Common analysis cluster: 0
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 1
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 2
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 3
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 4
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 5
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 6
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 7
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 8
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 9
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Common analysis cluster: 10
# common analysis progress: 10%
# common analysis progress: 20%
# common analysis progress: 30%
# common analysis progress: 40%
# common analysis progress: 50%
# common analysis progress: 60%
# common analysis progress: 70%
# common analysis progress: 80%
# common analysis progress: 90%
# common analysis progress: 100%
# Calculating differences
# Calculating Uniqueness

# %%
for cluster in unique_interactions:
    print(cluster, len(unique_interactions[cluster]))
# Out:
# 0 8830
# 1 54
# 2 150
# 3 41
# 4 25
# 5 164
# 6 36
# 7 132
# 8 513
# 9 67
# 10 21570

# %%
filtered_interactions = {}

for cluster in unique_interactions:
    filtered_interactions[cluster] = interactions.superset_filter(unique_interactions[cluster])
    print(cluster, len(filtered_interactions[cluster]))
# Out:
# 0 31
# 1 12
# 2 12
# 3 3
# 4 6
# 5 18
# 6 6
# 7 19
# 8 13
# 9 6
# 10 57

# %%
for cluster in filtered_interactions:
    print(f'Cluster {cluster}')
    print('=====================')
    for actions,percent in Counter(unique_interactions[cluster]).most_common(10):
        print(f'{percent:>6.4}', end=' ')
        format_actions(actions)
# Out:
# Cluster 0
# =====================
#    1.0 (WG_{i+-1} activate PH) + (CIR_i inhibit WG)
#    1.0 (SMO_i activate PH) + (CI_i inhibit en)
#    1.0 (EN_i inhibit ci) + (WG_{i+-1} activate PH) + (CIR_i inhibit WG)
#    1.0 (WG_{i+-1} activate PH) + (CIR_i inhibit PH) + (CIR_i inhibit WG)
#    1.0 (SLP_i activate WG) + (CIA_i activate SMO) + (SMO_i activate PH)
#    1.0 (SLP_i activate WG) + (CIA_i and SLP_i activate CI) + (CI_i inhibit en)
#    1.0 (SLP_i activate WG) + (SMO_i activate PH) + (CI_i inhibit en)
#    1.0 (CIA_i activate SMO) + (CIA_i and SLP_i activate CI) + (SMO_i activate PH)
#    1.0 (CIA_i activate SMO) + (EN_i activate HH) + (SMO_i activate PH)
#    1.0 (CIA_i activate SMO) + (SMO_i activate PH) + (CI_i inhibit en)
# Cluster 1
# =====================
# 0.9962 (CIA_i activate ptc) + (CIR_i inhibit wg) + (EN_i inhibit CI) + (CIR_i inhibit WG)
# 0.9962 (CIA_i activate ptc) + (CIR_i inhibit CIA) + (CIR_i inhibit wg) + (EN_i inhibit CI) + (CIR_i inhibit WG)
# 0.9946 (CIR_i inhibit wg) + (EN_i inhibit CI) + (CIR_i inhibit WG)
# 0.9946 (CIR_i inhibit CIA) + (CIR_i inhibit wg) + (EN_i inhibit CI) + (CIR_i inhibit WG)
# 0.9934 (SLP_i inhibit en) + (SLP_i and wg_i activate wg) + (CIR_i inhibit WG)
# 0.9934 (SLP_i inhibit en) + (EN_i inhibit ci) + (SLP_i and wg_i activate wg) + (CIR_i inhibit WG)
# 0.9934 (SLP_i and wg_i activate wg) + (CIR_i inhibit WG)
# 0.9934 (EN_i inhibit ci) + (SLP_i and wg_i activate wg) + (CIR_i inhibit WG)
#  0.991 (SLP_i inhibit en) + (CI_i activate SMO) + (CIR_i inhibit WG)
#  0.991 (CI_i activate SMO) + (SLP_i and wg_i activate wg) + (CIR_i inhibit WG)
# Cluster 2
# =====================
# 0.9999 (CIR_i inhibit ptc) + (CIA_i and SLP_i activate CIA) + (EN_i inhibit ptc)
# 0.9998 (CIR_i inhibit ptc) + (CIA_i and SLP_i activate CIA) + (EN_i inhibit CI)
# 0.9972 (CIR_i inhibit ptc) + (CIA_i and SLP_i activate CIA)
# 0.9962 (CIR_i inhibit ptc) + (SLP_i inhibit en) + (EN_i inhibit ptc)
# 0.9962 (CIR_i inhibit ptc) + (SLP_i inhibit en) + (EN_i inhibit ci) + (EN_i inhibit ptc)
# 0.9944 (CIA_i and SLP_i activate CIA) + (EN_i inhibit ptc)
# 0.9944 (CIR_i inhibit CIA) + (CIA_i and SLP_i activate CIA) + (EN_i inhibit ptc)
#  0.994 (CIA_i activate CI) + (CIA_i and SLP_i inhibit hh)
# 0.9934 (CIR_i inhibit ptc) + (CIA_i and SLP_i activate wg) + (EN_i inhibit ptc)
# 0.9932 (CIR_i inhibit ptc) + (EN_i inhibit ptc)
# Cluster 3
# =====================
# 0.9951 (CIA_i activate SMO) + (CIA_i and SLP_i activate wg) + (CI_i activate PTC)
# 0.9951 (CIA_i activate SMO) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg) + (CI_i activate PTC)
# 0.9947 (CIA_i activate SMO) + (CI_i activate PTC)
# 0.9947 (CIA_i activate SMO) + (CIR_i inhibit CIA) + (CI_i activate PTC)
# 0.9828 (CI_i and HH_{i+-1} activate ptc) + (CIA_i and SLP_i activate wg) + (EN_i inhibit CI) + (SLP_i activate CIA)
# 0.9828 (CI_i and HH_{i+-1} activate ptc) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg) + (EN_i inhibit CI) + (SLP_i activate CIA)
# 0.9827 (CI_i and HH_{i+-1} activate ptc) + (SLP_i inhibit en) + (EN_i inhibit CI) + (SLP_i activate CIA)
# 0.9827 (CI_i and HH_{i+-1} activate ptc) + (SLP_i inhibit en) + (CIA_i and SLP_i activate ptc)
# 0.9827 (CI_i and HH_{i+-1} activate ptc) + (SLP_i inhibit en) + (EN_i inhibit ci) + (CIA_i and SLP_i activate ptc)
# 0.9827 (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit CI) + (SLP_i activate CIA)
# Cluster 4
# =====================
# 0.9955 (PH_i activate SMO) + (EN_i inhibit wg) + (CI_i inhibit hh)
# 0.9914 (PH_i activate SMO) + (CIA_i activate ptc) + (CIR_i inhibit wg) + (EN_i inhibit CI)
# 0.9914 (PH_i activate SMO) + (CIA_i activate ptc) + (CIR_i inhibit CIA) + (CIR_i inhibit wg) + (EN_i inhibit CI)
# 0.9913 (PH_i activate SMO) + (CIR_i inhibit wg) + (EN_i inhibit CI)
# 0.9913 (PH_i activate SMO) + (CIR_i inhibit CIA) + (CIR_i inhibit wg) + (EN_i inhibit CI)
# 0.9876 (PH_i activate SMO) + (CIA_i activate ptc) + (EN_i inhibit CI)
# 0.9876 (PH_i activate SMO) + (CIA_i activate ptc) + (CIR_i inhibit CIA) + (EN_i inhibit CI)
# 0.9831 (EN_i inhibit wg) + (CI_i inhibit hh)
# 0.9829 (PH_i activate SMO) + (CI_i inhibit hh)
# 0.9814 (PH_i activate SMO) + (SLP_i inhibit en) + (EN_i inhibit CI)
# Cluster 5
# =====================
#  0.997 (PH_i activate SMO) + (SLP_i inhibit hh) + (EN_i activate hh) + (CIA_i activate PTC)
#  0.997 (PH_i activate SMO) + (SLP_i inhibit hh) + (SLP_i inhibit en) + (EN_i activate hh) + (CIA_i activate PTC)
#  0.997 (PH_i activate SMO) + (SLP_i inhibit hh) + (EN_i inhibit ci) + (EN_i activate hh) + (CIA_i activate PTC)
# 0.9963 (PH_i activate SMO) + (SLP_i inhibit hh) + (SLP_i inhibit en) + (EN_i activate hh)
# 0.9963 (PH_i activate SMO) + (SLP_i inhibit hh) + (SLP_i inhibit en) + (EN_i inhibit ci) + (EN_i activate hh)
# 0.9963 (PH_i activate SMO) + (SLP_i inhibit hh) + (EN_i activate hh)
# 0.9963 (PH_i activate SMO) + (SLP_i inhibit hh) + (EN_i inhibit ci) + (EN_i activate hh)
# 0.9959 (PH_i activate SMO) + (SLP_i inhibit en) + (EN_i activate hh) + (CIA_i activate PTC)
# 0.9959 (PH_i activate SMO) + (SLP_i inhibit en) + (EN_i inhibit ci) + (EN_i activate hh) + (CIA_i activate PTC)
# 0.9959 (PH_i activate SMO) + (EN_i activate hh) + (CIA_i activate PTC)
# Cluster 6
# =====================
# 0.9948 (CIA_i activate SMO) + (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH)
# 0.9948 (CIA_i activate SMO) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH)
#  0.993 (CIA_i activate SMO) + (PTC_i inhibit HH)
#  0.993 (CIA_i activate SMO) + (CIR_i inhibit CIA) + (PTC_i inhibit HH)
# 0.9928 (CIA_i activate SMO) + (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.9928 (CIA_i activate SMO) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.9928 (CIA_i activate SMO) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.9928 (CIA_i activate SMO) + (CIR_i inhibit CIA) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.9926 (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.9926 (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# Cluster 7
# =====================
#    1.0 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (SLP_i inhibit en) + (HH_{i+-1} activate PTC)
# 0.9999 (CI_i and SMO_i activate CIA) + (SMO_i inhibit CIR) + (HH_{i+-1} activate PTC)
# 0.9999 (CI_i and SMO_i activate CIA) + (SMO_i inhibit CIR) + (HH_{i+-1} activate SMO) + (HH_{i+-1} activate PTC)
# 0.9999 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (CIA_i and SLP_i activate wg) + (HH_{i+-1} activate PTC)
# 0.9999 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (HH_{i+-1} activate PTC)
# 0.9999 (CI_i and SMO_i activate CIA) + (HH_{i+-1} activate SMO) + (HH_{i+-1} activate PTC)
# 0.9998 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (HH_i inhibit PTC)
# 0.9998 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (SLP_i inhibit en) + (HH_i inhibit PTC)
# 0.9998 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (HH_i inhibit PTC) + (EN_i inhibit ci)
# 0.9998 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (HH_i inhibit PTC) + (EN_i activate hh)
# Cluster 8
# =====================
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (CIA_i and SLP_i activate wg) + (CIR_i inhibit en)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (CIA_i and SLP_i activate wg) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (PTC_i activate CIR) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (CIA_i and wg_i activate wg) + (CIR_i inhibit en)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (CIA_i and wg_i activate wg) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (EN_i inhibit ci) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (CI_i inhibit EN) + (CIR_i inhibit en) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (PTC_i activate CIR) + (CIA_i and wg_i activate wg) + (WG_i inhibit EN)
#    1.0 (EN_i inhibit PH) + (PTC_i activate CIR) + (CIR_i inhibit en) + (WG_i inhibit EN)
# Cluster 9
# =====================
# 0.9994 (CI_i and SMO_i inhibit CIR) + (SLP_i inhibit EN) + (CIA_i activate ptc) + (CIA_i and SLP_i activate wg)
# 0.9994 (CI_i and SMO_i inhibit CIR) + (SLP_i inhibit EN) + (EN_i inhibit PTC) + (HH_{i+-1} activate SMO)
# 0.9994 (CI_i and SMO_i inhibit CIR) + (SLP_i inhibit EN) + (CIA_i activate ptc) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg)
# 0.9993 (CI_i and SMO_i inhibit CIR) + (SLP_i inhibit EN) + (CIA_i and SLP_i activate wg)
# 0.9993 (CI_i and SMO_i inhibit CIR) + (SLP_i inhibit EN) + (HH_{i+-1} activate SMO)
# 0.9993 (CI_i and SMO_i inhibit CIR) + (SLP_i inhibit EN) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg)
# 0.9977 (SLP_i inhibit EN) + (EN_i inhibit PTC) + (HH_{i+-1} activate SMO)
# 0.9971 (CI_i and SMO_i inhibit CIR) + (EN_i inhibit PTC) + (HH_{i+-1} activate SMO)
# 0.9961 (CI_i and SMO_i inhibit CIR) + (CIA_i activate ptc) + (CIA_i and SLP_i activate wg)
# 0.9961 (CI_i and SMO_i inhibit CIR) + (CIA_i activate ptc) + (CIR_i inhibit CIA) + (CIA_i and SLP_i activate wg)
# Cluster 10
# =====================
#    1.0 (HH_i inhibit CI) + (SLP_i activate wg)
#    1.0 (EN_i activate PTC) + (CI_i and SMO_i activate EN)
#    1.0 (EN_i activate PTC) + (SLP_i activate wg)
#    1.0 (HH_i inhibit CI) + (SLP_i inhibit en) + (SLP_i activate wg)
#    1.0 (HH_i inhibit CI) + (HH_i inhibit PTC) + (CI_i inhibit HH)
#    1.0 (HH_i inhibit CI) + (HH_i inhibit PTC) + (CIA_i activate ptc)
#    1.0 (HH_i inhibit CI) + (HH_i inhibit PTC) + (CIR_i inhibit wg)
#    1.0 (HH_i inhibit CI) + (HH_i inhibit PTC) + (CI_i and SMO_i activate EN)
#    1.0 (HH_i inhibit CI) + (HH_i inhibit PTC) + (SLP_i activate wg)
#    1.0 (HH_i inhibit CI) + (EN_i inhibit ci) + (SLP_i activate wg)

# %% [markdown]
# ### Knockouts of common interactions

# %%
def simulate_knockouts(idx, interactions, models, verbose=False):
    n_models = len(models)

    knockout_simulations = {action:[0,0] for action in interactions}
    
    step = int(n_models/10)
    step = 1 if step == 0 else step
    
    i=0
    for model in models:
        if i%step==0 and verbose:
            print(f'{i/n_models*100:.0f}%')
        individual_cache = dict()

        for knockouts in interactions:
            individual_scores = []

            ko = SegmentPolarityModel(rules = model)
            ko = knockout_interactions(ko, knockouts)
            ko.compile_rules()
            state = SearchState(ko, 0,0,0,None)
            combined_score = state.getReward()

            if len(knockouts) > 1:
                for knockout in knockouts:
                    if knockout in individual_cache:
                        individual_scores.append(individual_cache[knockout])
                    else:
                        ko = SegmentPolarityModel(rules = model)
                        ko = knockout_interactions(ko, [knockout])
                        ko.compile_rules()
                        state = SearchState(ko, 0,0,0,None)
                        score = state.getReward()
                        individual_scores.append(score)
                        individual_cache[knockout] = score
            else:
                individual_scores.append(combined_score)

            knockout_simulations[knockouts][0] += combined_score/n_models
            knockout_simulations[knockouts][1] += (min(individual_scores) - combined_score)/n_models
        i+=1
    return (idx, knockout_simulations)

# %%
most_common_actions = []
sorted_common_actions = sorted(list(common_interactions.items()), key=lambda _:_[1], reverse=True)
for actions,pct in sorted_common_actions:
    # NOTE this only works when we're using order=[1]
    action = actions[0]
    if action not in predefined:
        if pct > .95:
            print(pct, end=" ")
            format_actions(actions)
            most_common_actions.append(actions)
        else:
            break
# Out:
# 1.0000000000007185 (EN_i inhibit ci)
# 1.0000000000007185 (CIR_i inhibit CIA)

# %%
combined_common_interactions = tuple([action[0] for action in most_common_actions])

# %%
_, common_knockout_scores = simulate_knockouts(0, [combined_common_interactions], random.sample(all_models, k=1000))
# Out:
# 0%

# %%
common_sorted_scores = sorted(common_knockout_scores.items(), key=lambda _:_[1])

for actions, (combined_score, synergy_score) in common_sorted_scores:
    print(f'{1-combined_score:.4f} {synergy_score:.4f}', end = " ")
    format_actions(actions)
# Out:
# 0.3113 0.0169 (EN_i inhibit ci) + (CIR_i inhibit CIA)

# %% [markdown]
# ### Comparison to knockouts of less common interactions

# %%
action_to_model = dict()
for i in range(len(all_models)):
    model = all_models[i]
    actions = action_set(model)
    for action in actions:
        if action in predefined:
            continue
        if action not in action_to_model: action_to_model[action] = list()
        action_to_model[action].append(i)

# %%
common_knockdown_scores = {}
for action, idxs in sorted(list(action_to_model.items()), key=lambda _:len(_[1]), reverse=True):
    sampled_models = []
    for idx in random.sample(idxs, k=min(len(idxs), 100)):
        sampled_models.append(all_models[idx])
    
    _, knockout_score = simulate_knockouts(0, [(action,)], sampled_models)
    _,(combined_score, _) = list(knockout_score.items())[0]
    common_knockdown_scores[action] = combined_score

# %%
for action, score in common_knockdown_scores.items():
    print(f'{1-score:.4f}', end=' ')
    format_actions((action,))
# Out:
# 0.2861 (EN_i inhibit ci)
# 0.1426 (CIR_i inhibit CIA)
# 0.0265 (SLP_i inhibit en)
# 0.0610 (CIA_i and SLP_i activate wg)
# 0.0668 (EN_i inhibit CI)
# 0.0342 (CIA_i activate ptc)
# 0.0686 (CI_i inhibit hh)
# 0.1004 (EN_i activate hh)
# 0.0281 (CIR_i inhibit WG)
# 0.0489 (CI_i and SMO_i activate ptc)
# 0.0437 (CIR_i inhibit wg)
# 0.0484 (HH_{i+-1} activate SMO)
# 0.0023 (SLP_i inhibit hh)
# 0.0131 (EN_i activate HH)
# 0.0747 (SLP_i and wg_i activate wg)
# 0.0087 (CIA_i activate SMO)
# 0.0389 (CIR_i inhibit SMO)
# 0.0007 (CIA_i activate PTC)
# 0.0416 (EN_i inhibit PTC)
# -0.0000 (WG_i activate SMO)
# -0.0000 (WG_i activate CI)
# -0.0000 (CIA_i and SLP_i activate CI)
# 0.0068 (PH_i inhibit EN)
# -0.0000 (EN_i inhibit wg)
# -0.0000 (WG_i activate CIA)
# 0.1875 (PTC_i inhibit HH)
# 0.0062 (PH_i activate SMO)
# 0.0006 (PTC_i activate CIR)
# -0.0000 (CI_i and SMO_i activate CIA)
# 0.0108 (EN_i inhibit ptc)
# 0.0002 (PH_i activate PTC)
# -0.0000 (HH_i activate SMO)
# -0.0000 (CIA_i activate CIR)
# 0.0092 (CIA_i activate CI)
# 0.0225 (CIR_i inhibit PH)
# -0.0000 (CIR_i inhibit hh)
# 0.0008 (CIR_i inhibit en)
# 0.0603 (SLP_i activate CIA)
# -0.0000 (WG_i inhibit EN)
# 0.0396 (HH_i inhibit PTC)
# 0.0345 (CI_i and SMO_i inhibit CIR)
# 0.0825 (SMO_i inhibit CIR)
# 0.0796 (CI_i inhibit en)
# -0.0000 (CIA_i and SLP_i activate CIR)
# 0.0128 (HH_i inhibit PH)
# 0.0342 (PH_i inhibit CIR)
# 0.0059 (SLP_i inhibit EN)
# 0.0032 (CI_i activate PTC)
# -0.0000 (CIA_i and wg_i activate wg)
# 0.0136 (CIR_i inhibit ptc)
# -0.0000 (CIA_i and SLP_i inhibit hh)
# -0.0000 (CI_i and HH_{i+-1} inhibit CIR)
# -0.0000 (CIA_i and SLP_i activate ptc)
# -0.0000 (WG_i activate CIR)
# 0.0838 (CI_i inhibit HH)
# 0.0012 (CIA_i activate PH)
# 0.0050 (CI_i activate SMO)
# -0.0000 (HH_i activate PTC)
# -0.0000 (PTC_i activate CIA)
# -0.0000 (SMO_i activate PH)
# -0.0000 (HH_{i+-1} activate PTC)
# -0.0000 (PH_{i+-1} activate PTC)
# 0.0077 (PH_i inhibit HH)
# -0.0000 (SMO_i activate HH)
# 0.0003 (WG_{i+-1} activate HH)
# 0.0542 (SLP_i activate WG)
# -0.0000 (WG_i inhibit HH)
# 0.0052 (EN_i inhibit CIA)
# -0.0000 (WG_i activate PH)
# -0.0000 (WG_{i+-1} activate PH)
# 0.0029 (HH_{i+-1} activate PH)
# -0.0000 (SLP_i activate CI)
# -0.0000 (CI_i and HH_{i+-1} activate CIR)
# -0.0000 (PH_i activate CIA)
# 0.0081 (PTC_i inhibit EN)
# -0.0000 (SLP_i activate PTC)
# -0.0000 (PH_i activate CI)
# -0.0000 (CIA_i activate HH)
# 0.1145 (CI_i inhibit EN)
# -0.0000 (SMO_{i+-1} activate HH)
# -0.0000 (CI_i and HH_{i+-1} activate CIA)
# 0.0187 (EN_i inhibit CIR)
# -0.0000 (CI_i and HH_{i+-1} inhibit hh)
# 0.0006 (EN_i inhibit PH)
# -0.0000 (CI_i and HH_{i+-1} inhibit en)
# 0.0599 (HH_i inhibit CI)
# 0.0612 (SLP_i activate wg)
# 0.0006 (CI_i and SMO_i inhibit en)
# -0.0000 (CI_i and SMO_i activate EN)
# -0.0000 (EN_i activate PTC)
# 0.0026 (CI_i and HH_{i+-1} activate ptc)
# -0.0000 (CIA_i and SLP_i activate CIA)
# -0.0000 (CIA_i and SLP_i activate EN)
# -0.0000 (PH_i activate HH)
# 0.0007 (EN_i inhibit WG)
# -0.0000 (CI_i and HH_{i+-1} inhibit EN)
# -0.0000 (CI_i and SMO_i activate CI)
# -0.0000 (CI_i and SMO_i activate en)
# -0.0000 (SLP_i activate PH)
# 0.0098 (HH_i inhibit CIA)
# -0.0000 (EN_i activate SMO)
# -0.0000 (CIA_i and SLP_i activate en)
# -0.0000 (CI_i and HH_{i+-1} activate EN)
# -0.0000 (PH_i activate CIR)
# 0.0127 (CI_i activate ptc)
# -0.0000 (PTC_i activate HH)
# -0.0000 (CI_i and HH_{i+-1} activate CI)
# 0.0002 (CI_i and SMO_i inhibit hh)
# -0.0000 (HH_i activate CIR)
# 0.0020 (WG_{i+-1} inhibit PH)
# -0.0000 (CIA_i and SLP_i activate hh)
# 0.0000 (SLP_i inhibit HH)
# 0.0037 (PTC_i activate CI)
# -0.0000 (WG_i activate PTC)
# 0.0001 (HH_i inhibit WG)
# 0.0009 (HH_i inhibit CIR)
# -0.0000 (CIA_i and SLP_i inhibit en)
# 0.0012 (CIR_i inhibit HH)
# 0.0002 (CIA_i and SLP_i inhibit EN)
# 0.0000 (PH_{i+-1} inhibit WG)
# -0.0000 (CI_i and SMO_i activate CIR)
# 0.0019 (CI_i and SMO_i inhibit EN)
# -0.0000 (PTC_{i+-1} activate PH)
# 0.0027 (CIR_i inhibit EN)
# -0.0000 (CI_i and HH_{i+-1} activate en)
# 0.0008 (PTC_i activate PH)
# -0.0000 (WG_i activate HH)
# 0.0007 (SMO_{i+-1} activate PTC)
# 0.0009 (WG_{i+-1} activate PTC)
# 0.0025 (SMO_i activate PTC)
# 0.0001 (SLP_i activate CIR)
# 0.0012 (WG_{i+-1} activate SMO)
# -0.0000 (PH_{i+-1} activate SMO)
# 0.0009 (PTC_{i+-1} activate HH)
# -0.0000 (SLP_i activate HH)
# -0.0000 (WG_i activate EN)
# -0.0000 (PH_{i+-1} activate HH)
# -0.0000 (CI_i activate HH)
# -0.0000 (CI_i activate PH)
# 0.0006 (CIA_i activate EN)
# -0.0000 (SLP_i activate ptc)
# -0.0000 (PTC_{i+-1} activate SMO)
# -0.0000 (EN_i activate CIR)
# 0.0005 (PTC_i activate SMO)
# -0.0000 (HH_i activate CI)
# -0.0000 (EN_i activate PH)
# 0.0002 (SMO_i activate CI)
# -0.0000 (SLP_i activate SMO)
# -0.0000 (CIA_i activate en)
# -0.0000 (SMO_{i+-1} activate PH)
# 0.0000 (CI_i activate EN)
# -0.0000 (PTC_i activate EN)
# 0.0012 (PH_i activate EN)
# 0.0000 (SLP_i activate EN)
# 0.0021 (HH_i activate WG)
# 0.0000 (HH_i activate PH)
# 0.0000 (CI_i and HH_{i+-1} activate hh)
# 0.0101 (CIA_i activate hh)
# -0.0000 (SMO_i activate CIR)
# 0.0015 (SMO_i activate CIA)
# 0.0000 (SLP_i activate en)
# -0.0000 (CI_i and SMO_i activate hh)
# -0.0000 (EN_i activate WG)
# 0.0000 (EN_i activate CIA)
# 0.0000 (HH_i activate CIA)
# 0.0283 (HH_i activate EN)
# 0.0000 (SLP_i activate hh)
# 0.0000 (PH_{i+-1} activate WG)
# 0.0000 (CI_i activate en)
# 0.0000 (CI_i activate ci)
# 0.0000 (PTC_{i+-1} activate WG)
# 0.0000 (EN_i activate CI)
# 0.0583 (WG_i inhibit CIR)

# %% [markdown]
# ### Knockout interactions that are unique to a given cluster
#
# Then simulate for each model in that cluster and determine how badly that destabilizes the behavior of those models.
#
# <!-- We do this for combinations of unique interactions as well -->

# %% [markdown]
# ### All clusters, unfiltered

# %%
# Split up the groups of interactions and models into evenly spaced groups
calls = []
n_samples = 100
step = 100
for cluster in clusters:
    # min call is to ensure that we get at most n_samples models.
    # If the cluster has less than n_samples models in it, then we'll just get all of them
    models = random.sample(clusters[cluster], k=(min(n_samples, len(clusters[cluster]))))
    interactions = list(unique_interactions[cluster].keys())
    for start in range(0, len(interactions), step):
        calls.append(
                delayed(simulate_knockouts)(
                    cluster, 
                    interactions[start:start+step], 
                    models)
                )

# %%
with Parallel(n_jobs=45, verbose=10) as parallel:
    parallel_knockout_simulations = parallel(calls)
# Out:
# [Parallel(n_jobs=45)]: Using backend LokyBackend with 45 concurrent workers.
# [Parallel(n_jobs=45)]: Done   8 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=45)]: Done  23 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=45)]: Done  38 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=45)]: Done  55 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=45)]: Done  72 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=45)]: Done  91 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=45)]: Done 110 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=45)]: Done 131 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=45)]: Done 152 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=45)]: Done 175 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=45)]: Done 198 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=45)]: Done 223 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=45)]: Done 266 out of 322 | elapsed: 19.1min remaining:  4.0min
# [Parallel(n_jobs=45)]: Done 299 out of 322 | elapsed: 21.0min remaining:  1.6min
# [Parallel(n_jobs=45)]: Done 322 out of 322 | elapsed: 21.5min finished

# %%
# Merge together the split up simulations
knockout_simulations = {}
for key,scores in parallel_knockout_simulations:
    if key not in knockout_simulations: knockout_simulations[key] = {}
    # this is a weird bit of code but it just merges two dictionaries
    knockout_simulations[key] = {**knockout_simulations[key], **scores}

# %%
action_counts = {}

for (cluster, simulation_scores) in knockout_simulations.items():
    print('Cluster', cluster)
    print('===================')
  
    # sort by the combined score first
    sorted_scores = sorted(simulation_scores.items(), key=lambda _:_[1])[:10]
    
    for actions, (combined_score, synergy_score) in sorted_scores:
        print(f'{1-combined_score:.4f} {synergy_score:.4f}', end = " ")
        format_actions(sorted(actions))
        for action in actions:
            if action not in action_counts: action_counts[action] = []
            action_counts[action].append(cluster)
# Out:
# Cluster 0
# ===================
# 0.3655 0.0894 (CI_i inhibit en) + (CIR_i inhibit PH) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (PH_i activate PTC)
# 0.3649 0.0888 (CI_i inhibit en) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (HH_i inhibit PH) + (PH_i activate PTC)
# 0.3643 0.0882 (CI_i inhibit en) + (CIA_i and SLP_i activate CI) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (PH_i activate PTC)
# 0.3613 0.0852 (CI_i inhibit en) + (CI_i and SMO_i activate ptc) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (PH_i activate PTC)
# 0.3608 0.0846 (CIA_i and SLP_i activate CI) + (CIR_i inhibit CIA) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (PH_i activate PTC)
# 0.3601 0.0840 (CI_i inhibit en) + (CIR_i inhibit WG) + (EN_i activate HH) + (EN_i inhibit ci) + (PH_i activate PTC)
# 0.3585 0.0864 (CIA_i and SLP_i activate CI) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (EN_i activate hh) + (PH_i activate PTC)
# 0.3565 0.0804 (CI_i inhibit en) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (PH_i activate PTC) + (WG_{i+-1} activate PH)
# 0.3556 0.0835 (CIA_i and SLP_i activate CI) + (CIR_i inhibit PH) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (PH_i activate PTC)
# 0.3554 0.0833 (CIA_i and SLP_i activate CI) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (HH_i inhibit PH) + (PH_i activate PTC)
# Cluster 1
# ===================
# 0.4069 0.1012 (CIR_i inhibit WG) + (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.4053 0.0995 (CIR_i inhibit WG) + (EN_i inhibit ci) + (HH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.4034 0.0977 (CI_i activate SMO) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.4016 0.0959 (EN_i inhibit ci) + (HH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.4002 0.0945 (CI_i activate SMO) + (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3821 0.0764 (CIR_i inhibit WG) + (EN_i inhibit ci) + (SLP_i and wg_i activate wg)
# 0.3805 0.0748 (CIR_i inhibit WG) + (EN_i inhibit ci) + (HH_i activate SMO) + (SLP_i and wg_i activate wg)
# 0.3785 0.0728 (CI_i activate SMO) + (CIR_i inhibit WG) + (EN_i inhibit ci) + (SLP_i and wg_i activate wg)
# 0.3772 0.0715 (EN_i inhibit ci) + (HH_i activate SMO) + (SLP_i and wg_i activate wg)
# 0.3756 0.0699 (CI_i activate SMO) + (EN_i inhibit ci) + (SLP_i and wg_i activate wg)
# Cluster 2
# ===================
# 0.3432 0.0373 (CIA_i and SLP_i inhibit hh) + (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i inhibit ptc) + (SLP_i inhibit en)
# 0.3427 0.0368 (CIA_i and SLP_i inhibit hh) + (CIR_i inhibit ptc) + (EN_i inhibit ci) + (SLP_i inhibit en)
# 0.3423 0.0364 (CIA_i and SLP_i inhibit hh) + (EN_i inhibit ci) + (EN_i inhibit ptc) + (SLP_i inhibit en)
# 0.3269 0.0209 (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i inhibit ptc) + (SLP_i inhibit en)
# 0.3204 0.0145 (CIA_i and SLP_i inhibit hh) + (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i inhibit ptc)
# 0.3203 0.0144 (CIA_i and SLP_i inhibit hh) + (CIR_i inhibit ptc) + (EN_i inhibit ci)
# 0.3186 0.0127 (CIA_i and SLP_i inhibit hh) + (EN_i inhibit ci) + (EN_i inhibit ptc)
# 0.3077 0.0018 (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i inhibit ptc)
# 0.1844 -0.0002 (CI_i inhibit hh) + (CIA_i activate CI)
# 0.1723 -0.0123 (CI_i inhibit hh) + (CIA_i activate CI) + (HH_{i+-1} activate SMO)
# Cluster 3
# ===================
# 0.4064 0.0314 (CI_i activate PTC) + (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit ci) + (SLP_i inhibit en)
# 0.4061 0.0312 (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit ci) + (SLP_i inhibit en)
# 0.3987 0.0237 (CIA_i and SLP_i activate ptc) + (EN_i inhibit ci) + (SLP_i inhibit en)
# 0.3958 0.0208 (CI_i and HH_{i+-1} activate ptc) + (CIA_i and SLP_i activate ptc) + (EN_i inhibit ci) + (SLP_i inhibit en)
# 0.3779 0.0029 (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit ci) + (SLP_i activate CIA) + (SLP_i inhibit en)
# 0.3749 -0.0001 (CI_i activate PTC) + (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit ci)
# 0.3747 -0.0003 (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit ci)
# 0.3664 -0.0086 (CI_i and HH_{i+-1} activate ptc) + (EN_i inhibit ci) + (SLP_i activate CIA)
# 0.3649 -0.0100 (CI_i and HH_{i+-1} activate ptc) + (CIA_i and SLP_i activate ptc) + (EN_i inhibit ci)
# 0.2244 0.0288 (CI_i and HH_{i+-1} activate ptc) + (CIR_i inhibit CIA) + (EN_i inhibit CI) + (SLP_i activate CIA)
# Cluster 4
# ===================
# 0.3934 0.0271 (CIR_i inhibit hh) + (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3850 0.0187 (CIR_i inhibit hh) + (EN_i inhibit ci) + (SLP_i and wg_i activate wg)
# 0.3848 0.0185 (CIR_i inhibit hh) + (EN_i inhibit ci) + (PH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3765 0.0101 (CIR_i inhibit hh) + (EN_i inhibit ci) + (PH_i activate SMO) + (SLP_i and wg_i activate wg)
# 0.3682 0.0019 (CIR_i inhibit hh) + (EN_i inhibit ci) + (PH_i activate SMO) + (SLP_i inhibit en)
# 0.3599 -0.0064 (CIR_i inhibit hh) + (EN_i inhibit ci) + (PH_i activate SMO)
# 0.2154 0.1057 (CIR_i inhibit CIA) + (CIR_i inhibit wg) + (EN_i inhibit CI) + (PH_i activate SMO)
# 0.1873 0.0768 (CIA_i activate ptc) + (CIR_i inhibit CIA) + (CIR_i inhibit wg) + (EN_i inhibit CI) + (PH_i activate SMO)
# 0.1831 0.0737 (CIR_i inhibit CIA) + (EN_i inhibit CI) + (PH_i activate SMO)
# 0.1535 0.0432 (CIA_i activate ptc) + (CIR_i inhibit CIA) + (EN_i inhibit CI) + (PH_i activate SMO)
# Cluster 5
# ===================
# 0.3740 0.1065 (CIA_i activate PTC) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3728 0.1052 (EN_i inhibit ci) + (EN_i activate hh) + (PH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3718 0.1043 (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3570 0.0895 (CIA_i activate PTC) + (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i inhibit hh) + (SLP_i and wg_i activate wg)
# 0.3559 0.0883 (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en) + (SLP_i inhibit hh) + (SLP_i and wg_i activate wg)
# 0.3548 0.0873 (EN_i inhibit ci) + (PH_i activate SMO) + (SLP_i inhibit en) + (SLP_i inhibit hh) + (SLP_i and wg_i activate wg)
# 0.3546 0.0871 (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i inhibit hh) + (SLP_i and wg_i activate wg)
# 0.3523 0.0848 (CIA_i activate PTC) + (EN_i inhibit ci) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3520 0.0845 (CIA_i activate PTC) + (EN_i inhibit ci) + (PH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.3389 0.0714 (CIA_i activate PTC) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i and wg_i activate wg)
# Cluster 6
# ===================
# 0.3106 0.0133 (EN_i inhibit ci) + (SLP_i activate CIA) + (SLP_i inhibit en) + (SLP_i inhibit hh)
# 0.2999 0.0026 (EN_i inhibit ci) + (SLP_i activate CIA) + (SLP_i inhibit hh)
# 0.2955 0.0603 (CIR_i inhibit CIA) + (PTC_i inhibit HH) + (SLP_i activate CIA) + (SLP_i inhibit hh)
# 0.2950 0.0597 (CIR_i inhibit CIA) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.2874 0.0521 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PTC_i inhibit HH) + (SLP_i inhibit hh)
# 0.2871 0.0518 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PTC_i inhibit HH) + (SLP_i activate CIA) + (SLP_i inhibit hh)
# 0.2866 0.0513 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PTC_i inhibit HH)
# 0.2863 0.0510 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.2429 0.0272 (CIR_i inhibit CIA) + (EN_i inhibit CI) + (SLP_i activate CIA) + (SLP_i inhibit hh)
# 0.2405 0.0247 (CIR_i inhibit CIA) + (SLP_i activate CIA) + (SLP_i inhibit hh)
# Cluster 7
# ===================
# 0.3111 0.0486 (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3111 0.0486 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3105 0.0481 (CI_i and SMO_i activate CIA) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3103 0.0478 (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh) + (HH_i inhibit PTC) + (SLP_i inhibit en)
# 0.3097 0.0473 (CI_i and SMO_i activate CIA) + (EN_i inhibit ci) + (EN_i activate hh) + (HH_i inhibit PTC) + (SLP_i inhibit en)
# 0.3083 0.0459 (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh)
# 0.3083 0.0459 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh)
# 0.3074 0.0450 (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh) + (HH_i inhibit PTC)
# 0.3074 0.0450 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (EN_i inhibit ci) + (EN_i activate hh) + (HH_i inhibit PTC)
# 0.3068 0.0444 (CI_i and SMO_i activate CIA) + (EN_i inhibit ci) + (EN_i activate hh) + (HH_i inhibit PTC)
# Cluster 8
# ===================
# 0.3906 0.0151 (CI_i inhibit EN) + (CIR_i inhibit en) + (EN_i inhibit PH) + (EN_i inhibit ci) + (WG_i inhibit EN)
# 0.3905 0.0150 (CI_i inhibit EN) + (CIR_i inhibit en) + (EN_i inhibit ci) + (WG_i inhibit EN)
# 0.3902 0.0147 (CI_i inhibit EN) + (CIR_i inhibit en) + (EN_i inhibit ci) + (EN_i inhibit ptc) + (WG_i inhibit EN)
# 0.3898 0.0143 (CI_i inhibit EN) + (EN_i inhibit PH) + (EN_i inhibit ci) + (WG_i inhibit EN)
# 0.3898 0.0143 (CI_i inhibit EN) + (EN_i inhibit ci) + (WG_i inhibit EN)
# 0.3896 0.0141 (CI_i inhibit EN) + (EN_i inhibit PH) + (EN_i inhibit ci) + (EN_i inhibit ptc) + (WG_i inhibit EN)
# 0.3896 0.0141 (CI_i inhibit EN) + (EN_i inhibit ci) + (EN_i inhibit ptc) + (WG_i inhibit EN)
# 0.3889 0.0134 (CI_i inhibit EN) + (CIR_i inhibit en) + (EN_i inhibit PH) + (EN_i inhibit ci)
# 0.3889 0.0134 (CI_i inhibit EN) + (CIR_i inhibit en) + (EN_i inhibit ci)
# 0.3887 0.0132 (CI_i inhibit EN) + (CIR_i inhibit en) + (EN_i inhibit ci) + (EN_i inhibit ptc)
# Cluster 9
# ===================
# 0.1909 0.0167 (CI_i and SMO_i inhibit CIR) + (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (SLP_i inhibit EN)
# 0.1909 0.0167 (CI_i and SMO_i inhibit CIR) + (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PH_{i+-1} activate PTC) + (SLP_i inhibit EN)
# 0.1908 0.0167 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (SLP_i inhibit EN)
# 0.1908 0.0167 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PH_{i+-1} activate PTC) + (SLP_i inhibit EN)
# 0.1901 0.0163 (CI_i and SMO_i inhibit CIR) + (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA)
# 0.1901 0.0163 (CI_i and SMO_i inhibit CIR) + (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PH_{i+-1} activate PTC)
# 0.1900 0.0162 (CIA_i and SLP_i activate wg) + (CIR_i inhibit CIA) + (PH_{i+-1} activate PTC)
# 0.1756 0.0014 (CIR_i inhibit CIA) + (SLP_i inhibit EN)
# 0.1756 0.0014 (CIR_i inhibit CIA) + (PH_{i+-1} activate PTC) + (SLP_i inhibit EN)
# 0.1753 0.0011 (CI_i and SMO_i inhibit CIR) + (CIR_i inhibit CIA) + (SLP_i inhibit EN)
# Cluster 10
# ===================
# 0.3704 0.1111 (CI_i inhibit HH) + (CIA_i activate CI) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3670 0.1118 (CIA_i activate CI) + (EN_i inhibit ci) + (EN_i activate hh) + (PH_i activate CI) + (SLP_i inhibit en)
# 0.3641 0.1048 (CI_i inhibit HH) + (EN_i inhibit ci) + (HH_i inhibit CI) + (HH_i inhibit PTC) + (PH_i inhibit EN)
# 0.3580 0.1028 (CIA_i activate CI) + (CIA_i activate ptc) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3575 0.1023 (CIA_i activate CI) + (EN_i activate PTC) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3567 0.0974 (CI_i inhibit HH) + (CIA_i activate CI) + (CIA_i activate ptc) + (EN_i inhibit ci) + (EN_i activate hh)
# 0.3561 0.0968 (CI_i inhibit HH) + (CIA_i activate CI) + (CIA_i activate ptc) + (EN_i inhibit ci) + (SLP_i inhibit en)
# 0.3556 0.0994 (CIA_i activate CI) + (CIR_i inhibit CIA) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3552 0.0960 (CI_i inhibit HH) + (CIR_i inhibit wg) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)
# 0.3544 0.0992 (CIA_i activate CI) + (CIR_i inhibit wg) + (EN_i inhibit ci) + (EN_i activate hh) + (SLP_i inhibit en)

# %%
max_disruptors = []

for (cluster, simulation_scores) in knockout_simulations.items():
    # sort by the combined score first
    max_disruptor, scores = min(simulation_scores.items(), key=lambda _:_[1])
    max_disruptors.append(set(max_disruptor))

# %%
from statistics import mean, median

# %% [markdown]
# ### Maximally disruptive sets are disjoint
#
# The sets of interactions that disrupt model behavior don't have many interactions in common

# %%
max_disruptor_similarities = []

for a,b in combinations(max_disruptors, r=2):
#     format_actions(a)
#     format_actions(b)
    print(f'inter: {len(a & b)}, union: {len(a|b)}, jaccard: {len(a & b)/len(a|b)}')
    max_disruptor_similarities.append(len(a & b)/len(a|b))
#     print('-')

print(max(max_disruptor_similarities))
print(mean(max_disruptor_similarities))
print(median(max_disruptor_similarities))
# Out:
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 1, union: 8, jaccard: 0.125
# inter: 1, union: 8, jaccard: 0.125
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 1, union: 8, jaccard: 0.125
# inter: 1, union: 8, jaccard: 0.125
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 0, union: 9, jaccard: 0.0
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 3, union: 5, jaccard: 0.6
# inter: 3, union: 6, jaccard: 0.5
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 1, union: 8, jaccard: 0.125
# inter: 0, union: 8, jaccard: 0.0
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 2, union: 8, jaccard: 0.25
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 3, union: 6, jaccard: 0.5
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 0, union: 9, jaccard: 0.0
# inter: 2, union: 8, jaccard: 0.25
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 1, union: 8, jaccard: 0.125
# inter: 0, union: 8, jaccard: 0.0
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 3, union: 6, jaccard: 0.5
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 1, union: 8, jaccard: 0.125
# inter: 0, union: 8, jaccard: 0.0
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 3, union: 6, jaccard: 0.5
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 0, union: 9, jaccard: 0.0
# inter: 3, union: 7, jaccard: 0.42857142857142855
# inter: 2, union: 6, jaccard: 0.3333333333333333
# inter: 1, union: 8, jaccard: 0.125
# inter: 0, union: 8, jaccard: 0.0
# inter: 2, union: 7, jaccard: 0.2857142857142857
# inter: 1, union: 8, jaccard: 0.125
# inter: 0, union: 8, jaccard: 0.0
# inter: 3, union: 6, jaccard: 0.5
# inter: 0, union: 9, jaccard: 0.0
# inter: 1, union: 9, jaccard: 0.1111111111111111
# inter: 0, union: 9, jaccard: 0.0
# 0.6
# 0.21953102453102452
# 0.25

# %%
action_counts = {}
cluster=7

simulation_scores = knockout_simulations[7]
print('Cluster', cluster)
print('===================')

# sort by the combined score first
sorted_scores = sorted(simulation_scores.items(), key=lambda _:_[1])[-20:]

for actions, (combined_score, synergy_score) in sorted_scores:
    print(f'{combined_score:.4f} {synergy_score:.4f}', end = " ")
    format_actions(sorted(actions))
    for action in actions:
        if action not in action_counts: action_counts[action] = []
        action_counts[action].append(cluster)
# Out:
# Cluster 7
# ===================
# 0.9606 0.0000 (CI_i and SMO_i activate CIA) + (HH_i inhibit PTC)
# 0.9770 0.0081 (CI_i and SMO_i activate ptc) + (CIR_i inhibit SMO) + (HH_{i+-1} activate PTC)
# 0.9770 0.0081 (CI_i and SMO_i activate CIA) + (CI_i and SMO_i activate ptc) + (CIR_i inhibit SMO) + (HH_{i+-1} activate PTC)
# 0.9787 0.0076 (CI_i and SMO_i activate ptc) + (HH_{i+-1} activate PTC)
# 0.9787 0.0076 (CI_i and SMO_i activate CIA) + (CI_i and SMO_i activate ptc) + (HH_{i+-1} activate PTC)
# 0.9846 0.0004 (CI_i and SMO_i activate ptc) + (CIR_i inhibit SMO)
# 0.9846 0.0004 (CI_i and SMO_i activate CIA) + (CI_i and SMO_i activate ptc) + (CIR_i inhibit SMO)
# 0.9863 0.0000 (CI_i and SMO_i activate CIA) + (CI_i and SMO_i activate ptc)
# 0.9957 0.0003 (CIR_i inhibit SMO) + (CIR_i inhibit ptc) + (HH_{i+-1} activate PTC)
# 0.9957 0.0003 (CI_i and SMO_i activate CIA) + (CIR_i inhibit SMO) + (CIR_i inhibit ptc) + (HH_{i+-1} activate PTC)
# 0.9958 0.0002 (CIR_i inhibit SMO) + (CIR_i inhibit ptc)
# 0.9958 0.0002 (CI_i and SMO_i activate CIA) + (CIR_i inhibit SMO) + (CIR_i inhibit ptc)
# 0.9975 0.0000 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc)
# 0.9975 0.0000 (CIR_i inhibit ptc) + (HH_{i+-1} activate PTC)
# 0.9975 0.0000 (CI_i and SMO_i activate CIA) + (CIR_i inhibit ptc) + (HH_{i+-1} activate PTC)
# 0.9982 0.0000 (CIR_i inhibit SMO) + (HH_{i+-1} activate PTC)
# 0.9982 0.0000 (CI_i and SMO_i activate CIA) + (CIR_i inhibit SMO) + (HH_{i+-1} activate PTC)
# 0.9983 0.0000 (CI_i and SMO_i activate CIA) + (CIR_i inhibit SMO)
# 1.0000 0.0000 (HH_{i+-1} activate PTC)
# 1.0000 0.0000 (CI_i and SMO_i activate CIA) + (HH_{i+-1} activate PTC)

# %%
for action, cluster_idxs in sorted(action_counts.items(), key=lambda _:len(_[1]), reverse=True):
    print(f'{len(cluster_idxs):3d}', end = ' ')
    format_actions((action,))
# Out:
#  85 (EN_i inhibit ci)
#  40 (SLP_i inhibit en)
#  25 (CIR_i inhibit CIA)
#  24 (EN_i activate hh)
#  24 (SLP_i and wg_i activate wg)
#  16 (CIR_i inhibit WG)
#  13 (CIR_i inhibit ptc)
#  11 (SLP_i activate CIA)
#  11 (PH_i activate SMO)
#  11 (SLP_i inhibit hh)
#  11 (CIA_i and SLP_i activate wg)
#  10 (PH_i activate PTC)
#  10 (EN_i inhibit ptc)
#  10 (CIA_i activate CI)
#  10 (CI_i inhibit EN)
#   9 (CI_i and HH_{i+-1} activate ptc)
#   7 (WG_i inhibit EN)
#   7 (SLP_i inhibit EN)
#   6 (CI_i inhibit en)
#   6 (CIA_i and SLP_i inhibit hh)
#   6 (EN_i inhibit CI)
#   6 (CIR_i inhibit hh)
#   6 (PTC_i inhibit HH)
#   6 (CI_i and SMO_i activate CIA)
#   6 (HH_i inhibit PTC)
#   6 (CIR_i inhibit en)
#   5 (CIA_i and SLP_i activate CI)
#   5 (CIA_i activate ptc)
#   5 (CIA_i activate PTC)
#   5 (CI_i and SMO_i inhibit CIR)
#   5 (PH_{i+-1} activate PTC)
#   5 (CI_i inhibit HH)
#   4 (HH_i activate SMO)
#   4 (CI_i activate SMO)
#   4 (CIR_i inhibit wg)
#   4 (EN_i inhibit PH)
#   3 (CIA_i and SLP_i activate ptc)
#   2 (CIR_i inhibit PH)
#   2 (HH_i inhibit PH)
#   2 (CI_i inhibit hh)
#   2 (CI_i activate PTC)
#   1 (CI_i and SMO_i activate ptc)
#   1 (EN_i activate HH)
#   1 (WG_{i+-1} activate PH)
#   1 (HH_{i+-1} activate SMO)
#   1 (PH_i activate CI)
#   1 (HH_i inhibit CI)
#   1 (PH_i inhibit EN)
#   1 (EN_i activate PTC)

# %% [markdown]
# ### All clusters (filtered for supersets)

# %%
# Split up the groups of interactions and models in which we are knocking them out into evenly spaced groups
calls = []
n_samples = 100
step = 100
for cluster in clusters:
    # min call is to ensure that we get at most n_samples models.
    # If the cluster has less than n_samples models in it, then we'll just get all of them
    models = random.sample(clusters[cluster], k=(min(n_samples, len(clusters[cluster]))))
    interactions = list(filtered_interactions[cluster].keys())
    for start in range(0, len(interactions), step):
        calls.append(
                delayed(simulate_knockouts)(
                    cluster, 
                    interactions[start:start+step], 
                    models)
                )

# %%
with Parallel(n_jobs=45, verbose=10) as parallel:
    parallel_knockout_simulations_filtered = parallel(calls)
# Out:
# [Parallel(n_jobs=45)]: Using backend LokyBackend with 45 concurrent workers.
# [Parallel(n_jobs=45)]: Done   2 out of  11 | elapsed:    9.0s remaining:   40.5s
# [Parallel(n_jobs=45)]: Done   4 out of  11 | elapsed:   11.2s remaining:   19.6s
# [Parallel(n_jobs=45)]: Done   6 out of  11 | elapsed:   17.2s remaining:   14.3s
# [Parallel(n_jobs=45)]: Done   8 out of  11 | elapsed:   24.0s remaining:    9.0s
# [Parallel(n_jobs=45)]: Done  11 out of  11 | elapsed:   58.7s finished

# %%
# Merge together the split up simulations
knockout_simulations_filtered = {}
for key,scores in parallel_knockout_simulations_filtered:
    if key not in knockout_simulations: knockout_simulations_filtered[key] = {}
    # this is a weird bit of code but it just merges two dictionaries
    knockout_simulations_filtered[key] = {**knockout_simulations[key], **scores}

# %%
action_counts = {}

for (cluster, simulation_scores) in knockout_simulations_filtered.items():
    print('Cluster', cluster)
    print('===================')
  
    # sort by the combined score first
    sorted_scores = sorted(simulation_scores.items(), key=lambda _:_[1])[:10]
    
    for actions, (combined_score, synergy_score) in sorted_scores:
        print(f'{combined_score:.4f} {synergy_score:.4f}', end = " ")
        format_actions(sorted(actions))
        for action in actions:
            if action not in action_counts: action_counts[action] = []
            action_counts[action].append(cluster)
# Out:
# Cluster 0
# ===================
# 0.8214 0.0097 (CI_i inhibit en) + (EN_i activate HH)
# 0.8304 0.0037 (CI_i inhibit en) + (CIA_i and SLP_i activate wg)
# 0.8322 0.0019 (CI_i inhibit en) + (CI_i and SMO_i activate ptc)
# 0.8328 0.0013 (CI_i inhibit en) + (CIA_i and SLP_i activate CI)
# 0.8533 -0.0255 (CI_i inhibit en) + (EN_i inhibit CI)
# 0.8616 -0.0276 (CI_i inhibit en) + (CIA_i activate SMO)
# 0.8653 0.0458 (CIR_i inhibit WG) + (EN_i activate HH) + (EN_i activate hh)
# 0.8705 0.0387 (CIR_i inhibit WG) + (EN_i inhibit CI) + (EN_i activate hh)
# 0.8883 0.0280 (CIR_i inhibit WG) + (EN_i inhibit CI) + (PH_i activate PTC)
# 0.9016 0.0177 (CIA_i and SLP_i activate wg) + (CIR_i inhibit WG) + (EN_i activate HH)
# Cluster 1
# ===================
# 0.6026 0.0937 (EN_i inhibit ci) + (HH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.6293 0.0670 (EN_i inhibit ci) + (HH_i activate SMO) + (SLP_i and wg_i activate wg)
# 0.8658 0.0382 (CI_i inhibit hh) + (CIR_i inhibit SMO)
# 0.8658 0.0465 (CIA_i activate ptc) + (CIR_i inhibit SMO)
# 0.8695 0.0435 (HH_i activate SMO) + (SLP_i inhibit en) + (SLP_i and wg_i activate wg)
# 0.8736 0.0244 (CIA_i activate ptc) + (CIR_i inhibit WG) + (EN_i inhibit CI)
# 0.9090 0.0088 (CIR_i inhibit WG) + (SLP_i and wg_i activate wg)
# 0.9113 0.0021 (CIR_i inhibit WG) + (EN_i inhibit CI) + (SLP_i inhibit en)
# 0.9176 0.0002 (HH_i activate SMO) + (SLP_i and wg_i activate wg)
# 0.9355 0.0087 (CIR_i inhibit SMO) + (CIR_i inhibit wg)
# Cluster 2
# ===================
# 0.8109 0.0000 (CI_i inhibit hh) + (CIA_i activate CI)
# 0.8406 0.0612 (CIA_i and SLP_i activate wg) + (CIR_i inhibit ptc) + (SLP_i inhibit en)
# 0.8850 0.0168 (CIA_i and SLP_i activate wg) + (EN_i inhibit ptc) + (SLP_i inhibit en)
# 0.8935 0.0448 (CIR_i inhibit ptc) + (EN_i inhibit CI)
# 0.9326 0.0112 (CIR_i inhibit ptc) + (EN_i inhibit ptc)
# 0.9423 0.0000 (CIA_i and SLP_i inhibit hh) + (EN_i inhibit CI)
# 0.9458 0.0000 (CIA_i and SLP_i inhibit hh) + (CIR_i inhibit ptc)
# 0.9498 -0.0075 (CIA_i activate CI) + (EN_i inhibit CI)
# 0.9838 0.0000 (CI_i activate ptc)
# 0.9875 0.0000 (CIA_i and SLP_i inhibit hh) + (EN_i inhibit ptc)
# Cluster 3
# ===================
# 0.9150 -0.0022 (CIA_i and SLP_i activate ptc) + (SLP_i inhibit en)
# 0.9883 0.0020 (CI_i activate PTC) + (CIA_i activate SMO)
# 0.9962 0.0000 (CI_i and HH_{i+-1} activate ptc)
# Cluster 4
# ===================
# 0.9118 0.0003 (CI_i inhibit hh) + (PH_i activate SMO)
# 0.9123 0.0000 (CI_i inhibit hh) + (EN_i inhibit wg)
# 0.9138 0.0001 (EN_i inhibit CI) + (PH_i activate SMO)
# 0.9538 -0.0065 (CIR_i inhibit hh) + (SLP_i and wg_i activate wg)
# 0.9952 0.0000 (CIR_i inhibit hh) + (PH_i activate SMO)
# 0.9952 0.0000 (EN_i inhibit wg) + (PH_i activate SMO)
# Cluster 5
# ===================
# 0.8708 0.1157 (CIA_i activate PTC) + (CIA_i activate ptc)
# 0.8864 0.0208 (EN_i activate hh) + (SLP_i and wg_i activate wg)
# 0.9091 0.0039 (CIA_i activate PTC) + (SLP_i and wg_i activate wg)
# 0.9100 0.0020 (SLP_i inhibit hh) + (SLP_i and wg_i activate wg)
# 0.9174 0.0000 (EN_i activate HH) + (EN_i inhibit PTC)
# 0.9204 0.0001 (EN_i inhibit PTC) + (SLP_i inhibit hh)
# 0.9215 0.0005 (EN_i inhibit PTC) + (PH_i activate SMO)
# 0.9379 0.0088 (EN_i activate HH) + (PH_i inhibit CIR)
# 0.9473 0.0004 (PH_i inhibit CIR) + (PH_i activate SMO)
# 0.9498 0.0208 (EN_i activate hh) + (PH_i activate SMO)
# Cluster 6
# ===================
# 0.7917 0.0181 (CIA_i and SLP_i activate wg) + (PTC_i inhibit HH)
# 0.8216 -0.0117 (PTC_i inhibit HH) + (SLP_i activate CIA)
# 0.8449 -0.0237 (CIA_i activate SMO) + (PTC_i inhibit HH)
# 0.8604 0.0277 (CI_i inhibit hh) + (CI_i and SMO_i activate ptc) + (CIA_i activate SMO)
# 0.8710 0.0170 (CI_i inhibit hh) + (CI_i and SMO_i activate ptc) + (SLP_i inhibit hh)
# 0.9151 0.0000 (SLP_i activate CIA) + (SLP_i inhibit hh)
# Cluster 7
# ===================
# 0.8455 0.0024 (CIR_i inhibit ptc) + (EN_i activate hh)
# 0.8914 0.0000 (CI_i and SMO_i activate CIA) + (CIA_i and SLP_i activate wg)
# 0.9096 0.0087 (CI_i and SMO_i activate ptc) + (CIR_i inhibit CIA) + (CIR_i inhibit SMO)
# 0.9156 0.0014 (CIR_i inhibit SMO) + (HH_{i+-1} activate SMO) + (SMO_i inhibit CIR)
# 0.9170 0.0013 (CI_i and SMO_i activate CIA) + (CIR_i inhibit CIA) + (CIR_i inhibit SMO)
# 0.9185 0.0007 (CI_i and SMO_i activate ptc) + (SMO_i inhibit CIR)
# 0.9187 0.0008 (CIR_i inhibit SMO) + (SMO_i inhibit CIR)
# 0.9195 0.0000 (CI_i and SMO_i activate CIA) + (SMO_i inhibit CIR)
# 0.9207 0.0030 (CI_i and SMO_i activate ptc) + (CIR_i inhibit SMO) + (HH_{i+-1} activate SMO)
# 0.9244 0.0000 (CI_i and SMO_i activate CIA) + (HH_{i+-1} activate SMO)
# Cluster 8
# ===================
# 0.8220 0.0000 (CI_i inhibit EN)
# 0.8388 0.0320 (CI_i inhibit hh) + (CI_i and SMO_i activate ptc) + (HH_{i+-1} activate SMO)
# 0.9157 0.0002 (CIA_i and SLP_i activate wg) + (CIR_i inhibit en)
# 0.9158 0.0000 (CIA_i and SLP_i activate wg) + (WG_i inhibit EN)
# 0.9607 0.0000 (EN_i inhibit ptc) + (WG_i inhibit EN)
# 0.9882 -0.0287 (CIR_i inhibit en) + (EN_i inhibit ptc)
# 0.9943 -0.0336 (EN_i inhibit ptc) + (PTC_i activate CIR)
# 0.9959 0.0000 (CIR_i inhibit en) + (PTC_i activate CIR)
# 0.9959 0.0000 (CIR_i inhibit en) + (WG_i inhibit EN)
# 0.9982 0.0000 (EN_i inhibit PH)
# Cluster 9
# ===================
# 0.9125 0.0000 (CIA_i and SLP_i activate wg) + (PH_{i+-1} activate PTC)
# 0.9535 0.0000 (CI_i and SMO_i inhibit CIR)
# 0.9575 0.0058 (EN_i inhibit PTC) + (HH_{i+-1} activate SMO)
# 0.9831 0.0000 (EN_i inhibit PTC) + (PH_{i+-1} activate PTC)
# 0.9940 0.0000 (SLP_i inhibit EN)
# 1.0000 0.0000 (HH_i activate PTC)
# Cluster 10
# ===================
# 0.7125 0.0470 (CIA_i activate CI) + (EN_i inhibit ci) + (HH_{i+-1} activate SMO)
# 0.7442 0.0153 (CIR_i inhibit wg) + (EN_i inhibit ci) + (HH_i activate SMO)
# 0.7519 0.0075 (EN_i inhibit ci) + (SMO_i inhibit CIR)
# 0.7567 0.0028 (CIA_i activate ptc) + (EN_i inhibit ci) + (HH_i activate SMO)
# 0.7584 0.0005 (CI_i activate PTC) + (CIR_i inhibit CIA) + (EN_i inhibit ci)
# 0.7614 -0.0026 (CIR_i inhibit CIA) + (EN_i inhibit ci) + (HH_i activate SMO)
# 0.8169 0.0000 (CI_i inhibit HH)
# 0.8190 0.0719 (CIA_i activate CI) + (CIR_i inhibit CIA) + (HH_{i+-1} activate SMO)
# 0.8311 0.0574 (CIR_i inhibit CIA) + (SMO_i inhibit CIR)
# 0.8603 0.0232 (CIR_i inhibit wg) + (EN_i activate hh)

# %% [markdown]
# ### Knockout unique interactions on other clusters
#
# This was meant to be a sanity check that knocking out unique interactions from one cluster doesn't affect models from another cluster. Because we're using higher order interactions (pairs of interactions) we don't exactly see perfect null results. The reason is that if a interaction pair is unique, either one of the interactions in the pair could occur individually in other clusters.

# %%
cross_cluster_knockouts = dict()
n_samples=50
for cluster_src in random.sample(unique_interactions.keys(), k=3):
    for cluster_other in random.sample(unique_interactions.keys(), k=3):
        if cluster_src != cluster_other:
            print('Unique interactions from cluster', cluster_src, 'knocked out in models from', cluster_other)
            models = random.sample(clusters[cluster_other], k=min(n_samples, len(clusters[cluster_other])))
            l = len(models)

            cross_cluster_knockouts[(cluster_src, cluster_other)] = dict()
            for action in unique_interactions[cluster_src]:
                cross_cluster_knockouts[(cluster_src, cluster_other)][action] = 0.0
                for model in models:
                    score = simulate_knockout(model, action)
                    cross_cluster_knockouts[(cluster_src, cluster_other)][action] += score/l

# %%
for cluster_src, cluster_other in cross_cluster_knockouts:
    print('Unique interactions from cluster', cluster_src, 'knocked out in models from', cluster_other)
    for actions, avg_reward in sorted(cross_cluster_knockouts[(cluster_src, cluster_other)].items(), key=lambda _:_[1])[:10]:
        print(f'{avg_reward:.3f}', end = " ")
        format_actions(actions)
